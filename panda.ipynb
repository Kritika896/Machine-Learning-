# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\kriti\OneDrive\Desktop\weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
rows, coloumns=df.shape
rows
# Out:
# 366

# %%
df.head()
# Out:
#           MinTemp  MaxTemp  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# Rainfall
# 0.0           8.0     24.3          3.4       6.3          NW           30.0
# 3.6          14.0     26.9          4.4       9.7         ENE           39.0
# 3.6          13.7     23.4          5.8       3.3          NW           85.0
# 39.8         13.3     15.5          7.2       9.1          NW           54.0
# 2.8           7.6     16.1          5.6      10.6         SSE           50.0
#
#          WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# Rainfall                                                    ...
# 0.0              SW         NW           6.0            20  ...           29
# 3.6               E          W           4.0            17  ...           36
# 3.6               N        NNE           6.0             6  ...           69
# 39.8            WNW          W          30.0            24  ...           56
# ...

# %%
df.tail()
# Out:
#           MinTemp  MaxTemp  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# Rainfall
# 0.0           9.0     30.7          7.6      12.1         NNW           76.0
# 0.0           7.1     28.4         11.6      12.7           N           48.0
# 0.0          12.5     19.9          8.4       5.3         ESE           43.0
# 0.0          12.5     26.9          5.0       7.1          NW           46.0
# 0.0          12.3     30.2          6.0      12.6          NW           78.0
#
#          WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# Rainfall                                                    ...
# 0.0             SSE         NW           7.0            50  ...           15
# 0.0             NNW        NNW           2.0            19  ...           22
# 0.0             ENE        ENE          11.0             9  ...           47
# 0.0             SSW        WNW           6.0            28  ...           39
# ...

# %%
df[2:5]
# Out:
#    Rainfall  MinTemp  MaxTemp  Evaporation  Sunshine WindGustDir  \
# 2       3.6     13.7     23.4          5.8       3.3          NW
# 3      39.8     13.3     15.5          7.2       9.1          NW
# 4       2.8      7.6     16.1          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
#
#    RISK_MM RainTomorrow
# 2     39.8          Yes
# 3      2.8          Yes
# 4      0.0           No
#
# ...

# %%
df.columns
# Out:
# Index(['Rainfall', 'MinTemp', 'MaxTemp', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.MinTemp
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
type(df['MinTemp'])
# Out:
# pandas.core.series.Series

# %%
df[['MinTemp','Rainfall']]
# Out:
#      MinTemp  Rainfall
# 0        8.0       0.0
# 1       14.0       3.6
# 2       13.7       3.6
# 3       13.3      39.8
# 4        7.6       2.8
# ..       ...       ...
# 361      9.0       0.0
# 362      7.1       0.0
# 363     12.5       0.0
# 364     12.5       0.0
# 365     12.3       0.0
#
# [366 rows x 2 columns]

# %%
df['Rainfall'].mean()
# Out:
# 1.4284153005464482

# %%
df.describe()
# Out:
#          Rainfall     MinTemp     MaxTemp  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     1.428415    7.265574   20.550273     4.521858    7.909366
# std      4.225800    6.025800    6.690516     2.669383    3.481517
# min      0.000000   -5.300000    7.600000     0.200000    0.000000
# 25%      0.000000    2.300000   15.025000     2.200000    5.950000
# 50%      0.000000    7.450000   19.650000     4.200000    8.600000
# 75%      0.200000   12.500000   25.500000     6.400000   10.500000
# max     39.800000   20.900000   35.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df[df.MinTemp==df.MinTemp.max()]
# Out:
#     Rainfall  MinTemp  MaxTemp  Evaporation  Sunshine WindGustDir  \
# 72       0.0     20.9     35.7         13.8       6.9          SW
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 72           50.0          E        WNW           4.0  ...           28
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 72       1007.6       1003.0         7         2     23.6     34.0         No
#
#     RISK_MM RainTomorrow
# 72      2.0          Yes
#
# [1 rows x 22 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
df.reset_index(inplace=True)
df
# Out:
#      index  Rainfall  MinTemp  MaxTemp  Evaporation  Sunshine WindGustDir  \
# 0        0       0.0      8.0     24.3          3.4       6.3          NW
# 1        1       3.6     14.0     26.9          4.4       9.7         ENE
# 2        2       3.6     13.7     23.4          5.8       3.3          NW
# 3        3      39.8     13.3     15.5          7.2       9.1          NW
# 4        4       2.8      7.6     16.1          5.6      10.6         SSE
# ..     ...       ...      ...      ...          ...       ...         ...
# 361    361       0.0      9.0     30.7          7.6      12.1         NNW
# 362    362       0.0      7.1     28.4         11.6      12.7           N
# 363    363       0.0     12.5     19.9          8.4       5.3         ESE
# 364    364       0.0     12.5     26.9          5.0       7.1          NW
# 365    365       0.0     12.3     30.2          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  Pressure9am  \
# ...

# %%
weather_data={
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'temperature':[32,35,28],
    'event':['Rain','sunny','snow']
}
df= pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  sunny
# 2  1/3/2017           28   snow

# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\kriti\OneDrive\Desktop\weather.csv",header=None,names=["ticket","hello","right"])
df
# Out:
#                                                                                                                                                                                                               ticket  \
# MinTemp MaxTemp Rainfall Evaporation Sunshine WindGustDir WindGustSpeed WindDir9am WindDir3pm WindSpeed9am WindSpeed3pm Humidity9am Humidity3pm Pressure9am Pressure3pm Cloud9am Cloud3pm Temp9am Temp3pm  RainToday
# 8       24.3    0        3.4         6.3      NW          30            SW         NW         6            20           68          29          1019.7      1015        7        7        14.4    23.6            No
# 14      26.9    3.6      4.4         9.7      ENE         39            E          W          4            17           80          36          1012.4      1008.4      5        3        17.5    25.7           Yes
# ...

# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\kriti\OneDrive\Desktop\weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\kriti\OneDrive\Desktop\weather.csv",nrows=3)
df
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30         SW         NW             6  ...           29
# 1             39          E          W             4  ...           36
# 2             85          N        NNE             6  ...           69
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
# 2     39.8          Yes
#
# ...

# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\kriti\Downloads\archive (2)\weatherData.csv")
df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR               NaN
#
# ...

# %%
new_df=df.fillna(0)
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR               0.0
#
# ...

# %%
new_df=df.fillna({
    'HourlyVisibility':0,
    'HourlyWindSpeed':'no windspeed',
})
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR               0.0
#
# ...

# %%
new_df=df.fillna(method="ffill")
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR              10.0
#
# ...

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR               NaN
#
# ...

# %%
new_df=df.fillna(method="ffill",limit=1)
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR              10.0
#
# ...

# %%
new_df=df.interpolate()
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8753  2018      9   15    19          747              CLR              10.0
# 8754  2018      9   15    20          747              CLR              10.0
# 8755  2018      9   15    21          747              CLR              10.0
# 8756  2018      9   15    22          747              CLR              10.0
# 8757  2018      9   15    23          747              CLR              10.0
#
# ...

# %%
new_df=df.dropna()
new_df
# Out:
#       Year  Month  Day  Hour  SunlightMin HourlySkyWeather  HourlyVisibility  \
# 0     2017      9   16     0          747              CLR               7.0
# 1     2017      9   16     1          747              CLR               6.0
# 2     2017      9   16     2          747              CLR               4.0
# 3     2017      9   16     3          747              CLR               3.0
# 4     2017      9   16     4          747              CLR               3.0
# ...    ...    ...  ...   ...          ...              ...               ...
# 8673  2018      9   12     9          757              OVC               2.5
# 8674  2018      9   12    10          757              OVC               4.0
# 8675  2018      9   12    11          757              OVC               5.0
# 8676  2018      9   12    12          757              OVC               8.0
# 8677  2018      9   12    13          757              OVC               8.0
#
# ...

# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\kriti\OneDrive\Desktop\weather.csv")
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
g=df.groupby('WindGustDir')
g

# %%
for WindGustDir,WindGustDir_df in g:
    print(WindGustDir)
    print(WindGustDir_df)
# Out:
# E
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 7        8.3     17.0       0.0          5.6       4.6           E
# 9        8.4     22.8      16.2          5.4       7.7           E
# 11       8.5     27.3       0.2          7.2      12.5           E
# 15      12.4     32.1       0.0          8.4      11.1           E
# 18      12.4     32.3       0.6          7.4      13.0           E
# 21      16.4     19.4       0.4          9.2       0.0           E
# 25      15.6     26.9       0.0          6.8       8.9           E
# 43       8.9     27.1       0.0          4.4      12.7           E
# 44      10.1     29.9       0.0          6.8       8.8           E
# 54      11.3     21.7       3.4          8.2       5.6           E
# 59      15.4     35.0       0.0          9.6      13.0           E
# 68      16.5     30.3       0.0         10.0       8.1           E
# 69      17.5     29.9       0.0          6.6       8.8           E
# ...

# %%
g.mean()
# Out:
#                MinTemp    MaxTemp  Rainfall  Evaporation   Sunshine  \
# WindGustDir
# E             9.981081  24.086486  0.718919     5.567568   8.600000
# ENE          11.213333  23.333333  1.720000     5.860000   7.910000
# ESE           9.169565  20.821739  2.000000     4.852174   5.978261
# N             2.919048  18.538095  0.400000     4.047619   9.209524
# NE           10.750000  25.893750  1.425000     6.075000   8.981250
# NNE          10.275000  23.737500  0.575000     3.575000   7.971429
# NNW           6.022727  20.459091  1.463636     4.368182   8.018182
# NW            6.131507  19.478082  2.084932     4.084932   8.108333
# S             5.131818  17.013636  1.372727     3.563636   7.759091
# SE            7.183333  18.491667  0.100000     4.250000   5.808333
# SSE           7.600000  18.750000  2.616667     4.416667   7.100000
# SSW           7.640000  23.400000  0.000000     5.000000   6.950000
# SW           14.566667  27.000000  0.000000     6.933333   7.500000
# ...

# %%
g.describe()
# Out:
#             MinTemp                                                          \
#               count       mean       std   min     25%    50%     75%   max
# WindGustDir
# E              37.0   9.981081  5.017903  -0.9   7.400  10.10  15.200  17.5
# ENE            30.0  11.213333  4.301702  -0.1   9.125  11.75  13.825  18.2
# ESE            23.0   9.169565  6.319338  -3.5   5.800  10.10  14.050  17.6
# N              21.0   2.919048  5.455513  -2.7  -0.900   1.40   4.400  17.9
# NE             16.0  10.750000  5.316014  -0.2   9.650  11.90  14.800  16.5
# NNE             8.0  10.275000  3.915081   4.6   6.900  11.80  12.925  14.9
# NNW            44.0   6.022727  6.400286  -3.7   0.800   4.35  12.725  19.9
# NW             73.0   6.131507  5.573496  -5.3   1.800   5.30  11.300  18.0
# S              22.0   5.131818  5.511752  -2.2   1.275   4.60   7.775  16.3
# SE             12.0   7.183333  4.995786   0.2   4.500   6.15  10.450  15.1
# ...

# %%
# %matplotlib inline 
g.plot()
# Out:
# WindGustDir
# E      AxesSubplot(0.125,0.125;0.775x0.755)
# ENE    AxesSubplot(0.125,0.125;0.775x0.755)
# ESE    AxesSubplot(0.125,0.125;0.775x0.755)
# N      AxesSubplot(0.125,0.125;0.775x0.755)
# NE     AxesSubplot(0.125,0.125;0.775x0.755)
# NNE    AxesSubplot(0.125,0.125;0.775x0.755)
# NNW    AxesSubplot(0.125,0.125;0.775x0.755)
# NW     AxesSubplot(0.125,0.125;0.775x0.755)
# S      AxesSubplot(0.125,0.125;0.775x0.755)
# SE     AxesSubplot(0.125,0.125;0.775x0.755)
# SSE    AxesSubplot(0.125,0.125;0.775x0.755)
# SSW    AxesSubplot(0.125,0.125;0.775x0.755)
# SW     AxesSubplot(0.125,0.125;0.775x0.755)
# W      AxesSubplot(0.125,0.125;0.775x0.755)
# WNW    AxesSubplot(0.125,0.125;0.775x0.755)
# WSW    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
import pandas as pd

india_weather=pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temperture":[32,45,30],
    "humidity":[80,60,78]
})
india_weather
# Out:
#        city  temperture  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78

# %%
import pandas as pd

USA_weather=pd.DataFrame({
    "city":["NewYork","Chicago","orlando"],
    "temperture":[21,14,35],
    "humidity":[68,65,75]
})
USA_weather
# Out:
#       city  temperture  humidity
# 0  NewYork          21        68
# 1  Chicago          14        65
# 2  orlando          35        75

# %%
df=pd.concat([india_weather,USA_weather])
df
# Out:
#        city  temperture  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78
# 0   NewYork          21        68
# 1   Chicago          14        65
# 2   orlando          35        75

# %%
df=pd.concat([india_weather,USA_weather],ignore_index=True)
df
# Out:
#        city  temperture  humidity
# 0    mumbai          32        80
# 1     delhi          45        60
# 2  banglore          30        78
# 3   NewYork          21        68
# 4   Chicago          14        65
# 5   orlando          35        75

# %%
df=pd.concat([india_weather,USA_weather],keys=["india","USA"])
df
# Out:
#              city  temperture  humidity
# india 0    mumbai          32        80
#       1     delhi          45        60
#       2  banglore          30        78
# USA   0   NewYork          21        68
#       1   Chicago          14        65
#       2   orlando          35        75

# %%
df.loc["USA"]
# Out:
#       city  temperture  humidity
# 0  NewYork          21        68
# 1  Chicago          14        65
# 2  orlando          35        75

# %%
windspeed_df=pd.DataFrame({
    "city":["NewYork","Chicago","orlando"],
    "Windspeed":[2,4,5],
    
})
windspeed_df
# Out:
#       city  Windspeed
# 0  NewYork          2
# 1  Chicago          4
# 2  orlando          5

# %%
temp_df=pd.DataFrame({
    "city":["NewYork","Chicago","orlando"],
    "Temp":[21,41,51],
    
})
temp_df
# Out:
#       city  Temp
# 0  NewYork    21
# 1  Chicago    41
# 2  orlando    51

# %%
df=pd.concat([temp_df,windspeed_df],axis=1)
df
# Out:
#       city  Temp     city  Windspeed
# 0  NewYork    21  NewYork          2
# 1  Chicago    41  Chicago          4
# 2  orlando    51  orlando          5

# %%
#join dataframe with series

s=pd.Series(["Humid","dry","rain"],name="event")
s
# Out:
# 0    Humid
# 1      dry
# 2     rain
# Name: event, dtype: object

# %%
df=pd.concat([temp_df,s],axis=1)
df
# Out:
#       city  Temp  event
# 0  NewYork    21  Humid
# 1  Chicago    41    dry
# 2  orlando    51   rain

# %%
df3=pd.merge(temp_df,windspeed_df,on="city")
df3
# Out:
#       city  Temp  Windspeed
# 0  NewYork    21          2
# 1  Chicago    41          4
# 2  orlando    51          5

# %%
df3.pivot(index='Windspeed',columns="city")
# Out:
#              Temp
# city      Chicago NewYork orlando
# Windspeed
# 2             NaN    21.0     NaN
# 4            41.0     NaN     NaN
# 5             NaN     NaN    51.0

# %%
weather_data={
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'city':['newyork','washington','seattle'],
    'temperature':[32,35,28],
    'event':['Rain','sunny','snow']
}
df= pd.DataFrame(weather_data)
df
# Out:
#         day        city  temperature  event
# 0  1/1/2017     newyork           32   Rain
# 1  1/2/2017  washington           35  sunny
# 2  1/3/2017     seattle           28   snow

# %%
df.pivot(index="day",columns="city",values="event")
# Out:
# city     newyork seattle washington
# day
# 1/1/2017    Rain     NaN        NaN
# 1/2/2017     NaN     NaN      sunny
# 1/3/2017     NaN    snow        NaN

# %%
df.pivot(index="city",columns="day",margins=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-7d23b820fed1> in <module>
# ----> 1 df.pivot(index="city",columns="day",margins=True)
#
# TypeError: pivot() got an unexpected keyword argument 'margins'
